# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvir007/GAZIPUR-AIR-POLLUTION/blob/main/Gazipur_Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data science/new/Gazipur_air_Pollutant.xlsx - Sheet1.csv')
df.head
# Out:
# <bound method NDFrame.head of          PM25    PM10   SO2    NO2     CO     O3
# 0      148.67  183.25  0.13   6.17  1.930   7.46
# 1      121.70  150.06  0.10   7.67  1.100  14.29
# 2       86.93  159.96  0.38  15.27  0.860   6.19
# 3      261.00  349.00  0.69   4.33  2.310   4.10
# 4       97.05  189.53  0.09   7.16  0.780   7.57
# ...       ...     ...   ...    ...    ...    ...
# 12427  199.64  425.76  2.46  37.95  2.683   3.89
# 12428  212.79  428.93  1.62  34.87  2.601   3.82
# 12429  236.64  441.44  1.23  21.08  2.892   4.37
# 12430   62.43   75.20  2.62   4.14  2.646   1.32
# 12431   61.05   79.88  0.64  12.94  2.298   0.22
#
# [12432 rows x 6 columns]>

# %%
mean1=df.SO2.mean()
df.SO2 = df.SO2.fillna(mean1)
df.SO2
# Out:
# 0        0.13
# 1        0.10
# 2        0.38
# 3        0.69
# 4        0.09
#          ...
# 12427    2.46
# 12428    1.62
# 12429    1.23
# 12430    2.62
# 12431    0.64
# Name: SO2, Length: 12432, dtype: float64

# %%
mean2=df.CO.mean()
df.CO = df.CO.fillna(mean2)
df.CO
# Out:
# 0        1.930
# 1        1.100
# 2        0.860
# 3        2.310
# 4        0.780
#          ...
# 12427    2.683
# 12428    2.601
# 12429    2.892
# 12430    2.646
# 12431    2.298
# Name: CO, Length: 12432, dtype: float64

# %%
mean3=df.PM25.mean()
df.PM25 = df.PM25.fillna(mean3)
df.PM25
# Out:
# 0        148.67
# 1        121.70
# 2         86.93
# 3        261.00
# 4         97.05
#           ...
# 12427    199.64
# 12428    212.79
# 12429    236.64
# 12430     62.43
# 12431     61.05
# Name: PM25, Length: 12432, dtype: float64

# %%
mean4=df.PM10.mean()
df.PM10 = df.PM10.fillna(mean4)
df.PM10
# Out:
# 0        183.25
# 1        150.06
# 2        159.96
# 3        349.00
# 4        189.53
#           ...
# 12427    425.76
# 12428    428.93
# 12429    441.44
# 12430     75.20
# 12431     79.88
# Name: PM10, Length: 12432, dtype: float64

# %%
mean6=df.NO2.mean()
df.NO2 = df.NO2.fillna(mean6)
df.NO2
# Out:
# 0         6.17
# 1         7.67
# 2        15.27
# 3         4.33
# 4         7.16
#          ...
# 12427    37.95
# 12428    34.87
# 12429    21.08
# 12430     4.14
# 12431    12.94
# Name: NO2, Length: 12432, dtype: float64

# %%
df.info
# Out:
# <bound method DataFrame.info of          PM25    PM10   SO2    NO2     CO     O3
# 0      148.67  183.25  0.13   6.17  1.930   7.46
# 1      121.70  150.06  0.10   7.67  1.100  14.29
# 2       86.93  159.96  0.38  15.27  0.860   6.19
# 3      261.00  349.00  0.69   4.33  2.310   4.10
# 4       97.05  189.53  0.09   7.16  0.780   7.57
# ...       ...     ...   ...    ...    ...    ...
# 12427  199.64  425.76  2.46  37.95  2.683   3.89
# 12428  212.79  428.93  1.62  34.87  2.601   3.82
# 12429  236.64  441.44  1.23  21.08  2.892   4.37
# 12430   62.43   75.20  2.62   4.14  2.646   1.32
# 12431   61.05   79.88  0.64  12.94  2.298   0.22
#
# [12432 rows x 6 columns]>

# %%
df.describe()
# Out:
#                PM25          PM10           SO2           NO2            CO  \
# count  12432.000000  12432.000000  12432.000000  12432.000000  12432.000000
# mean     125.553500    206.133390      8.649561      9.269552      1.904708
# std       91.663217    149.518102     11.385435     10.325428      1.050024
# min        0.020000      0.050000      0.040000      0.040000      0.010000
# 25%       50.187500     93.587500      2.480000      1.660000      1.220000
# 50%      105.645000    178.145000      5.720000      5.770000      1.760000
# 75%      182.097500    274.682500     10.840000     13.340000      2.490000
# max      534.950000    935.870000    268.340000     91.000000     11.650000
#
#                  O3
# count  12432.000000
# mean       6.866025
# std       11.638262
# min        0.050000
# 25%        0.570000
# 50%        1.340000
# 75%        8.740000
# max      135.080000

# %%
df.corr()
# Out:
#           PM25      PM10       SO2       NO2        CO        O3
# PM25  1.000000  0.909871  0.084052  0.391743  0.469937 -0.142955
# PM10  0.909871  1.000000  0.093655  0.394091  0.453870 -0.129210
# SO2   0.084052  0.093655  1.000000  0.166349  0.076647  0.019919
# NO2   0.391743  0.394091  0.166349  1.000000  0.229499  0.006070
# CO    0.469937  0.453870  0.076647  0.229499  1.000000 -0.196443
# O3   -0.142955 -0.129210  0.019919  0.006070 -0.196443  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x = df.drop(['PM25'],axis = 1)

# %%
x
# Out:
#          PM10   SO2    NO2     CO     O3
# 0      183.25  0.13   6.17  1.930   7.46
# 1      150.06  0.10   7.67  1.100  14.29
# 2      159.96  0.38  15.27  0.860   6.19
# 3      349.00  0.69   4.33  2.310   4.10
# 4      189.53  0.09   7.16  0.780   7.57
# ...       ...   ...    ...    ...    ...
# 12427  425.76  2.46  37.95  2.683   3.89
# 12428  428.93  1.62  34.87  2.601   3.82
# 12429  441.44  1.23  21.08  2.892   4.37
# 12430   75.20  2.62   4.14  2.646   1.32
# 12431   79.88  0.64  12.94  2.298   0.22
#
# [12432 rows x 5 columns]

# %%
y = df.PM25

# %%
y
# Out:
# 0        148.67
# 1        121.70
# 2         86.93
# 3        261.00
# 4         97.05
#           ...
# 12427    199.64
# 12428    212.79
# 12429    236.64
# 12430     62.43
# 12431     61.05
# Name: PM25, Length: 12432, dtype: float64

# %%
from sklearn.datasets import make_blobs

x, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(x[:, 0], x[:, 1], c=y, s=50, cmap='rainbow');

# %%
#import library
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.30, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
pred = regressor.predict(xtest)

# %%
pred
# Out:
# array([ 1.16876777,  0.29815899,  1.04405304,  0.157147  ,  2.13599917,
#         2.49133235,  1.1345157 ,  1.9238225 ,  2.03262549,  2.15639933,
#         0.07786834,  1.41785454,  1.72896497,  1.79613948,  1.42217206,
#         1.74481153,  0.92576028,  1.35086731,  0.6346751 ,  1.33597278,
#         1.40167   ,  0.23951932,  0.95205948,  1.88532684,  0.41470152,
#         2.45417339,  2.11927915,  2.36178292,  1.66898633,  0.62793797,
#         2.80457775,  2.92552829,  1.75805425,  1.71908289,  1.48922796,
#         2.44230793,  0.35519588,  2.28702147,  2.0400564 , -0.4274591 ,
#         2.56677658,  2.33941093,  1.35544786,  2.51884619,  1.65543565,
#         1.80135797,  0.49349709,  2.28034327,  0.9255205 ,  1.59549817,
#         1.96642185,  0.85045691,  0.76974983,  0.10119332,  0.86494698,
#         1.4866014 ,  0.89899053,  0.67796636,  0.36804517,  1.67720543,
#         2.24805043,  1.94239657,  1.63362409,  2.62942028, -0.17125034,
# ...

# %%
regressor.score(xtest,ytest)
# Out:
# 0.46693977720760105

# %%
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
sns.pairplot(df,x_vars=['SO2','CO','PM10','NO2','O3'],y_vars='PM25',height=7,aspect=0.7)

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(ytest,pred)

# %%
score
# Out:
# 0.46693977720760105

# %%
print(regressor.intercept_)
# Out:
# 1.1083739831094641

# %%
print(regressor.coef_)
# Out:
# [-0.34885899  0.09296148]

# %%
list(zip(['SO2','CO','PM10','NO2','O3'],regressor.coef_))
# Out:
# [('SO2', -0.3488589857887092), ('CO', 0.09296148497157532)]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
regressor.coef_
# Out:
# array([-0.34885899,  0.09296148])

# %%
regressor.intercept_
# Out:
# 1.1083739831094641

# %%
y = -0.34885899*10+ 0.09296148*2 +1.1083739831094641

# %%
y
# Out:
# -2.1942929568905356

# %%
regressor.predict([[10,2]])
# Out:
# array([-2.1942929])
