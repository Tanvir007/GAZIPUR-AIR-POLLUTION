# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvir007/GAZIPUR-AIR-POLLUTION/blob/main/Gazipur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data science/Gazipur.csv')
df.head
# Out:
# <bound method NDFrame.head of        SO2      CO    PM25    PM10     NO   NO2
# 0      NaN  0.9200   69.29  104.55  33.01  8.46
# 1      NaN  0.9200   79.08   91.07  41.15  6.06
# 2      NaN  0.9400   82.03   92.97  45.87  2.84
# 3      NaN  0.8300   82.66   91.91  51.41  3.26
# 4      NaN  0.9800   71.83   89.55  66.11  5.15
# ...    ...     ...     ...     ...    ...   ...
# 80347  NaN  3.4104  154.25  430.35   9.83   NaN
# 80348  NaN  3.2040  151.17  395.90  11.58   NaN
# 80349  NaN  3.3900  183.08  388.70  13.33   NaN
# 80350  NaN  3.2880  159.19  322.41  13.74   NaN
# 80351  NaN  3.2004  132.95  235.67  11.44   NaN
#
# [80352 rows x 6 columns]>

# %%
df.shape
# Out:
# (80352, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of        SO2      CO    PM25    PM10     NO   NO2
# 0      NaN  0.9200   69.29  104.55  33.01  8.46
# 1      NaN  0.9200   79.08   91.07  41.15  6.06
# 2      NaN  0.9400   82.03   92.97  45.87  2.84
# 3      NaN  0.8300   82.66   91.91  51.41  3.26
# 4      NaN  0.9800   71.83   89.55  66.11  5.15
# ...    ...     ...     ...     ...    ...   ...
# 80347  NaN  3.4104  154.25  430.35   9.83   NaN
# 80348  NaN  3.2040  151.17  395.90  11.58   NaN
# 80349  NaN  3.3900  183.08  388.70  13.33   NaN
# 80350  NaN  3.2880  159.19  322.41  13.74   NaN
# 80351  NaN  3.2004  132.95  235.67  11.44   NaN
#
# [80352 rows x 6 columns]>

# %%
df.isnull().any()
# Out:
# SO2     True
# CO      True
# PM25    True
# PM10    True
# NO      True
# NO2     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# SO2     43595
# CO      35204
# PM25    25085
# PM10    28049
# NO      39160
# NO2     41582
# dtype: int64

# %%
df.SO2
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 80347   NaN
# 80348   NaN
# 80349   NaN
# 80350   NaN
# 80351   NaN
# Name: SO2, Length: 80352, dtype: float64

# %%
mean1=df.SO2.mean()

# %%
df.SO2 = df.SO2.fillna(mean1)

# %%
df.SO2
# Out:
# 0        10.257805
# 1        10.257805
# 2        10.257805
# 3        10.257805
# 4        10.257805
#            ...
# 80347    10.257805
# 80348    10.257805
# 80349    10.257805
# 80350    10.257805
# 80351    10.257805
# Name: SO2, Length: 80352, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80352 entries, 0 to 80351
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SO2     80352 non-null  float64
#  1   CO      45148 non-null  float64
#  2   PM25    55267 non-null  float64
#  3   PM10    52303 non-null  float64
#  4   NO      41192 non-null  float64
#  5   NO2     38770 non-null  float64
# dtypes: float64(6)
# memory usage: 3.7 MB

# %%
mean2=df.CO.mean()

# %%
df.CO = df.CO.fillna(mean2)

# %%
df.CO
# Out:
# 0        0.9200
# 1        0.9200
# 2        0.9400
# 3        0.8300
# 4        0.9800
#           ...
# 80347    3.4104
# 80348    3.2040
# 80349    3.3900
# 80350    3.2880
# 80351    3.2004
# Name: CO, Length: 80352, dtype: float64

# %%
mean3=df.PM25.mean()

# %%
df.PM25 = df.PM25.fillna(mean3)

# %%
df.PM25.isnull().sum()
# Out:
# 0

# %%
mean4=df.PM10.mean()

# %%
df.PM10 = df.PM10.fillna(mean4)

# %%
mean5=df.NO.mean()

# %%
df.NO = df.NO.fillna(mean5)

# %%
mean6=df.NO2.mean()

# %%
df.NO2 = df.NO2.fillna(mean6)

# %%
df.info
# Out:
# <bound method DataFrame.info of              SO2      CO    PM25    PM10     NO       NO2
# 0      10.257805  0.9200   69.29  104.55  33.01  8.460000
# 1      10.257805  0.9200   79.08   91.07  41.15  6.060000
# 2      10.257805  0.9400   82.03   92.97  45.87  2.840000
# 3      10.257805  0.8300   82.66   91.91  51.41  3.260000
# 4      10.257805  0.9800   71.83   89.55  66.11  5.150000
# ...          ...     ...     ...     ...    ...       ...
# 80347  10.257805  3.4104  154.25  430.35   9.83  9.245389
# 80348  10.257805  3.2040  151.17  395.90  11.58  9.245389
# 80349  10.257805  3.3900  183.08  388.70  13.33  9.245389
# 80350  10.257805  3.2880  159.19  322.41  13.74  9.245389
# 80351  10.257805  3.2004  132.95  235.67  11.44  9.245389
#
# [80352 rows x 6 columns]>

# %%
df.isnull().sum()
# Out:
# SO2     0
# CO      0
# PM25    0
# PM10    0
# NO      0
# NO2     0
# dtype: int64

# %%
df.describe()
# Out:
#                 SO2            CO          PM25          PM10            NO  \
# count  80352.000000  80352.000000  80352.000000  80352.000000  80352.000000
# mean      10.257805      1.791771     92.151584    155.933542     19.904189
# std       10.372736      0.850315     69.722594    111.957056     24.259891
# min        0.010000      0.010000      0.020000      0.050000      0.010000
# 25%        5.900000      1.460000     41.630000     82.000000      7.430000
# 50%       10.257805      1.791771     92.151584    155.933542     19.904189
# 75%       10.257805      1.805250     94.160000    155.933542     19.904189
# max      277.300000     33.660000    867.730000    981.920000    398.800000
#
#                 NO2
# count  80352.000000
# mean       9.245389
# std        7.420471
# min        0.040000
# 25%        5.990000
# 50%        9.245389
# 75%        9.245389
# max      180.150000

# %%
df['PM25'].value_counts()
# Out:
# 92.151584     25085
# 17.000000        93
# 11.000000        87
# 27.000000        86
# 12.000000        84
#               ...
# 84.340000         1
# 218.240000        1
# 222.790000        1
# 129.530000        1
# 69.770000         1
# Name: PM25, Length: 20611, dtype: int64

# %%
df.describe()
# Out:
#                 SO2            CO          PM25          PM10            NO  \
# count  80352.000000  80352.000000  80352.000000  80352.000000  80352.000000
# mean      10.257805      1.791771     92.151584    155.933542     19.904189
# std       10.372736      0.850315     69.722594    111.957056     24.259891
# min        0.010000      0.010000      0.020000      0.050000      0.010000
# 25%        5.900000      1.460000     41.630000     82.000000      7.430000
# 50%       10.257805      1.791771     92.151584    155.933542     19.904189
# 75%       10.257805      1.805250     94.160000    155.933542     19.904189
# max      277.300000     33.660000    867.730000    981.920000    398.800000
#
#                 NO2
# count  80352.000000
# mean       9.245389
# std        7.420471
# min        0.040000
# 25%        5.990000
# 50%        9.245389
# 75%        9.245389
# max      180.150000

# %%
df.corr()
# Out:
#            SO2        CO      PM25      PM10        NO       NO2
# SO2   1.000000  0.027411  0.055431  0.045179  0.040566 -0.067951
# CO    0.027411  1.000000  0.346618  0.371935  0.261217  0.183567
# PM25  0.055431  0.346618  1.000000  0.809342  0.238653  0.291163
# PM10  0.045179  0.371935  0.809342  1.000000  0.221619  0.316381
# NO    0.040566  0.261217  0.238653  0.221619  1.000000  0.268921
# NO2  -0.067951  0.183567  0.291163  0.316381  0.268921  1.000000

# %%
x = df.drop(['PM25'],axis = 1)

# %%
x
# Out:
#              SO2      CO    PM10     NO       NO2
# 0      10.257805  0.9200  104.55  33.01  8.460000
# 1      10.257805  0.9200   91.07  41.15  6.060000
# 2      10.257805  0.9400   92.97  45.87  2.840000
# 3      10.257805  0.8300   91.91  51.41  3.260000
# 4      10.257805  0.9800   89.55  66.11  5.150000
# ...          ...     ...     ...    ...       ...
# 80347  10.257805  3.4104  430.35   9.83  9.245389
# 80348  10.257805  3.2040  395.90  11.58  9.245389
# 80349  10.257805  3.3900  388.70  13.33  9.245389
# 80350  10.257805  3.2880  322.41  13.74  9.245389
# 80351  10.257805  3.2004  235.67  11.44  9.245389
#
# [80352 rows x 5 columns]

# %%
y = df.PM25

# %%
y
# Out:
# 0         69.29
# 1         79.08
# 2         82.03
# 3         82.66
# 4         71.83
#           ...
# 80347    154.25
# 80348    151.17
# 80349    183.08
# 80350    159.19
# 80351    132.95
# Name: PM25, Length: 80352, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = .30,random_state = 1)

# %%
xtrain
# Out:
#              SO2        CO        PM10          NO       NO2
# 26172  10.257805  0.640000   84.060000    0.220000  1.100000
# 44310  10.257805  3.580000  194.630000   19.904189  9.245389
# 37102  53.420000  1.791771  155.933542   19.904189  0.300000
# 44382  10.257805  2.550000  205.980000   19.904189  9.245389
# 17472  10.257805  0.900000  152.410000   19.904189  9.245389
# ...          ...       ...         ...         ...       ...
# 21440  10.750000  1.940000  100.970000    1.540000  3.830000
# 73349   1.360000  3.159000  340.650000  111.920000  6.850000
# 50057  62.060000  1.791771   23.070000    1.140000  0.170000
# 5192    6.810000  1.760000   71.250000   19.040000  0.500000
# 77708  10.257805  2.748000  155.933542    7.390000  9.245389
#
# [56246 rows x 5 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
model.score(xtest,ytest)
# Out:
# 0.7431437224146975

# %%
ypredict = model.predict(xtest)

# %%
ypredict
# Out:
# array([ 86.35881148, 149.09284751, 115.10549252, ...,  85.42017261,
#         29.51626378,  59.17611176])

# %%
df=pd.DataFrame({'Actual':ytest, 'Predicted':ypredict})
df
# Out:
#            Actual   Predicted
# 66230   92.151584   86.358811
# 18061  169.750000  149.092848
# 12878   39.700000  115.105493
# 61502   92.151584   86.358811
# 34496   92.151584   86.358811
# ...           ...         ...
# 77856   16.830000   14.223191
# 32810   13.210000   41.170656
# 20497  108.110000   85.420173
# 16559   22.320000   29.516264
# 15567   18.000000   59.176112
#
# [24106 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(ytest, ypredict))
print('Mean Squared Error:', metrics.mean_squared_error(ytest, ypredict))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ytest, ypredict)))
# Out:
# Mean Absolute Error: 22.401111037843073
# Mean Squared Error: 1259.0308128396796
# Root Mean Squared Error: 35.48282419480839

# %%
# Calculate the absolute errors
errors = abs(ypredict - ytest)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / ytest)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 22.4 degrees.
# Accuracy: 37.82 %.

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))


ax = sns.distplot(y, hist=False, color="r", label="Actual Value")
sns.distplot(ypredict, hist=False, color="b", label="Fitted Values" , ax=ax)


plt.title('Actual vs Fitted Values for Concentration')


plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
Tree = model.estimators_[5]
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
Tree = model.estimators_[5]
# Export the image to a dot file
from sklearn import tree
plt.figure(figsize=(25,15))
tree.plot_tree(Tree,filled=True, 
              rounded=True, 
              fontsize=14);

# %%
from sklearn.datasets import load_wine

wine = load_wine()
x = wine.data
y = wine.target

# %%
rf = RandomForestRegressor(n_estimators=100, 
                            max_depth=3,
                            max_features='auto', 
                            min_samples_leaf=4,
                            bootstrap=True, 
                            n_jobs=-1, 
                            random_state=0)
rf.fit(x, y)
# Out:
# RandomForestRegressor(max_depth=3, min_samples_leaf=4, n_jobs=-1,
#                       random_state=0)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(15, 10))
plot_tree(rf.estimators_[0], 
          feature_names=wine.feature_names,
          class_names=wine.target_names, 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(0.5416666666666666, 0.875, 'od280/od315_of_diluted_wines <= 2.375\nsquared_error = 0.565\nsamples = 112\nvalue = 0.949'),
#  Text(0.3333333333333333, 0.625, 'hue <= 0.898\nsquared_error = 0.172\nsamples = 38\nvalue = 1.78'),
#  Text(0.16666666666666666, 0.375, 'proline <= 490.0\nsquared_error = 0.021\nsamples = 28\nvalue = 1.978'),
#  Text(0.08333333333333333, 0.125, 'squared_error = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(0.25, 0.125, 'squared_error = 0.0\nsamples = 24\nvalue = 2.0'),
#  Text(0.5, 0.375, 'hue <= 1.035\nsquared_error = 0.071\nsamples = 10\nvalue = 1.077'),
#  Text(0.4166666666666667, 0.125, 'squared_error = 0.188\nsamples = 4\nvalue = 1.25'),
#  Text(0.5833333333333334, 0.125, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.75, 0.625, 'proline <= 726.5\nsquared_error = 0.249\nsamples = 74\nvalue = 0.538'),
#  Text(0.6666666666666666, 0.375, 'squared_error = 0.0\nsamples = 37\nvalue = 1.0'),
# ...

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_data = export_graphviz(rf.estimators_[99], 
                           feature_names=wine.feature_names,
                           class_names=wine.target_names, 
                           filled=True, impurity=True, 
                           rounded=True)

graph = graphviz.Source(dot_data, format='png')
graph

# %%
sns.heatmap(df.corr(),annot=True)

# %%
rf.score(x,y)
# Out:
# 0.9724572688077567

# %%
rf.predict([[10,.64,80,0.54,1.4,1.2,1.3,1.6,1.6,1.9,2.1,4,5]])
# Out:
# array([1.00987146])
