# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvir007/GAZIPUR-AIR-POLLUTION/blob/main/Gazipur_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data science/Gazipur.csv')
df.head
# Out:
# <bound method NDFrame.head of        SO2      CO    PM25    PM10     NO   NO2
# 0      NaN  0.9200   69.29  104.55  33.01  8.46
# 1      NaN  0.9200   79.08   91.07  41.15  6.06
# 2      NaN  0.9400   82.03   92.97  45.87  2.84
# 3      NaN  0.8300   82.66   91.91  51.41  3.26
# 4      NaN  0.9800   71.83   89.55  66.11  5.15
# ...    ...     ...     ...     ...    ...   ...
# 80347  NaN  3.4104  154.25  430.35   9.83   NaN
# 80348  NaN  3.2040  151.17  395.90  11.58   NaN
# 80349  NaN  3.3900  183.08  388.70  13.33   NaN
# 80350  NaN  3.2880  159.19  322.41  13.74   NaN
# 80351  NaN  3.2004  132.95  235.67  11.44   NaN
#
# [80352 rows x 6 columns]>

# %%
mean1=df.SO2.mean()
df.SO2 = df.SO2.fillna(mean1)
df.SO2
# Out:
# 0        10.257805
# 1        10.257805
# 2        10.257805
# 3        10.257805
# 4        10.257805
#            ...
# 80347    10.257805
# 80348    10.257805
# 80349    10.257805
# 80350    10.257805
# 80351    10.257805
# Name: SO2, Length: 80352, dtype: float64

# %%
mean2=df.CO.mean()
df.CO = df.CO.fillna(mean2)
df.CO
# Out:
# 0        0.9200
# 1        0.9200
# 2        0.9400
# 3        0.8300
# 4        0.9800
#           ...
# 80347    3.4104
# 80348    3.2040
# 80349    3.3900
# 80350    3.2880
# 80351    3.2004
# Name: CO, Length: 80352, dtype: float64

# %%
mean3=df.PM25.mean()
df.PM25 = df.PM25.fillna(mean3)
df.PM25
# Out:
# 0         69.29
# 1         79.08
# 2         82.03
# 3         82.66
# 4         71.83
#           ...
# 80347    154.25
# 80348    151.17
# 80349    183.08
# 80350    159.19
# 80351    132.95
# Name: PM25, Length: 80352, dtype: float64

# %%
mean4=df.PM10.mean()
df.PM10 = df.PM10.fillna(mean4)
df.PM10
# Out:
# 0        104.55
# 1         91.07
# 2         92.97
# 3         91.91
# 4         89.55
#           ...
# 80347    430.35
# 80348    395.90
# 80349    388.70
# 80350    322.41
# 80351    235.67
# Name: PM10, Length: 80352, dtype: float64

# %%
mean5=df.NO.mean()
df.NO = df.NO.fillna(mean5)
df.NO
# Out:
# 0        33.01
# 1        41.15
# 2        45.87
# 3        51.41
# 4        66.11
#          ...
# 80347     9.83
# 80348    11.58
# 80349    13.33
# 80350    13.74
# 80351    11.44
# Name: NO, Length: 80352, dtype: float64

# %%
mean6=df.NO2.mean()
df.NO2 = df.NO2.fillna(mean6)
df.NO2
# Out:
# 0        8.460000
# 1        6.060000
# 2        2.840000
# 3        3.260000
# 4        5.150000
#            ...
# 80347    9.245389
# 80348    9.245389
# 80349    9.245389
# 80350    9.245389
# 80351    9.245389
# Name: NO2, Length: 80352, dtype: float64

# %%
df.info
# Out:
# <bound method DataFrame.info of              SO2      CO    PM25    PM10     NO       NO2
# 0      10.257805  0.9200   69.29  104.55  33.01  8.460000
# 1      10.257805  0.9200   79.08   91.07  41.15  6.060000
# 2      10.257805  0.9400   82.03   92.97  45.87  2.840000
# 3      10.257805  0.8300   82.66   91.91  51.41  3.260000
# 4      10.257805  0.9800   71.83   89.55  66.11  5.150000
# ...          ...     ...     ...     ...    ...       ...
# 80347  10.257805  3.4104  154.25  430.35   9.83  9.245389
# 80348  10.257805  3.2040  151.17  395.90  11.58  9.245389
# 80349  10.257805  3.3900  183.08  388.70  13.33  9.245389
# 80350  10.257805  3.2880  159.19  322.41  13.74  9.245389
# 80351  10.257805  3.2004  132.95  235.67  11.44  9.245389
#
# [80352 rows x 6 columns]>

# %%
df.describe()
# Out:
#                 SO2            CO          PM25          PM10            NO  \
# count  80352.000000  80352.000000  80352.000000  80352.000000  80352.000000
# mean      10.257805      1.791771     92.151584    155.933542     19.904189
# std       10.372736      0.850315     69.722594    111.957056     24.259891
# min        0.010000      0.010000      0.020000      0.050000      0.010000
# 25%        5.900000      1.460000     41.630000     82.000000      7.430000
# 50%       10.257805      1.791771     92.151584    155.933542     19.904189
# 75%       10.257805      1.805250     94.160000    155.933542     19.904189
# max      277.300000     33.660000    867.730000    981.920000    398.800000
#
#                 NO2
# count  80352.000000
# mean       9.245389
# std        7.420471
# min        0.040000
# 25%        5.990000
# 50%        9.245389
# 75%        9.245389
# max      180.150000

# %%
df.corr()
# Out:
#            SO2        CO      PM25      PM10        NO       NO2
# SO2   1.000000  0.027411  0.055431  0.045179  0.040566 -0.067951
# CO    0.027411  1.000000  0.346618  0.371935  0.261217  0.183567
# PM25  0.055431  0.346618  1.000000  0.809342  0.238653  0.291163
# PM10  0.045179  0.371935  0.809342  1.000000  0.221619  0.316381
# NO    0.040566  0.261217  0.238653  0.221619  1.000000  0.268921
# NO2  -0.067951  0.183567  0.291163  0.316381  0.268921  1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
x = df.drop(['PM25'],axis = 1)

# %%
x
# Out:
#              SO2      CO    PM10     NO       NO2
# 0      10.257805  0.9200  104.55  33.01  8.460000
# 1      10.257805  0.9200   91.07  41.15  6.060000
# 2      10.257805  0.9400   92.97  45.87  2.840000
# 3      10.257805  0.8300   91.91  51.41  3.260000
# 4      10.257805  0.9800   89.55  66.11  5.150000
# ...          ...     ...     ...    ...       ...
# 80347  10.257805  3.4104  430.35   9.83  9.245389
# 80348  10.257805  3.2040  395.90  11.58  9.245389
# 80349  10.257805  3.3900  388.70  13.33  9.245389
# 80350  10.257805  3.2880  322.41  13.74  9.245389
# 80351  10.257805  3.2004  235.67  11.44  9.245389
#
# [80352 rows x 5 columns]

# %%
y = df.PM25

# %%
y
# Out:
# 0         69.29
# 1         79.08
# 2         82.03
# 3         82.66
# 4         71.83
#           ...
# 80347    154.25
# 80348    151.17
# 80349    183.08
# 80350    159.19
# 80351    132.95
# Name: PM25, Length: 80352, dtype: float64

# %%
from sklearn.datasets import make_blobs

x, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(x[:, 0], x[:, 1], c=y, s=50, cmap='rainbow');

# %%
#import library
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.30, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
pred = regressor.predict(xtest)

# %%
pred
# Out:
# array([ 1.16876777,  0.29815899,  1.04405304,  0.157147  ,  2.13599917,
#         2.49133235,  1.1345157 ,  1.9238225 ,  2.03262549,  2.15639933,
#         0.07786834,  1.41785454,  1.72896497,  1.79613948,  1.42217206,
#         1.74481153,  0.92576028,  1.35086731,  0.6346751 ,  1.33597278,
#         1.40167   ,  0.23951932,  0.95205948,  1.88532684,  0.41470152,
#         2.45417339,  2.11927915,  2.36178292,  1.66898633,  0.62793797,
#         2.80457775,  2.92552829,  1.75805425,  1.71908289,  1.48922796,
#         2.44230793,  0.35519588,  2.28702147,  2.0400564 , -0.4274591 ,
#         2.56677658,  2.33941093,  1.35544786,  2.51884619,  1.65543565,
#         1.80135797,  0.49349709,  2.28034327,  0.9255205 ,  1.59549817,
#         1.96642185,  0.85045691,  0.76974983,  0.10119332,  0.86494698,
#         1.4866014 ,  0.89899053,  0.67796636,  0.36804517,  1.67720543,
#         2.24805043,  1.94239657,  1.63362409,  2.62942028, -0.17125034,
# ...

# %%
regressor.score(xtest,ytest)
# Out:
# 0.46693977720760105

# %%
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
sns.pairplot(df,x_vars=['SO2','CO','PM10','NO','NO2'],y_vars='PM25',height=7,aspect=0.7)

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(ytest,pred)

# %%
score
# Out:
# 0.46693977720760105

# %%
print(regressor.intercept_)
# Out:
# 1.1083739831094641

# %%
print(regressor.coef_)
# Out:
# [-0.34885899  0.09296148]

# %%
list(zip(['SO2','CO','PM10','NO','NO2'],regressor.coef_))
# Out:
# [('SO2', -0.3488589857887092), ('CO', 0.09296148497157532)]

# %%
sns.heatmap(df.corr(),annot=True)

# %%
regressor.coef_
# Out:
# array([-0.34885899,  0.09296148])

# %%
regressor.intercept_
# Out:
# 1.1083739831094641

# %%
y = -0.34885899*10+ 0.09296148*2 +1.1083739831094641

# %%
y
# Out:
# -2.1942929568905356

# %%
regressor.predict([[10,2]])
# Out:
# array([-2.1942929])
